# %% [markdown]
# **Scraping Google Images**
#
# by Kridha

# %%
# install bing image donwloader
# !pip install bing-image-downloader

# %%
# file directory
# !mkdir dataset_batik

# %%
from bing_image_downloader import downloader

downloader.download('batik pesisir', limit = 300, output_dir='dataset_batik',
                    adult_filter_off=True)
# Out:
# [%] Downloading Images to /content/dataset_batik/batik truntum
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://elle.co.id/wp-content/uploads/2020/10/batik_truntum.jpg
# [Error]Invalid image, not saving https://elle.co.id/wp-content/uploads/2020/10/batik_truntum.jpg
#
# [!] Issue getting: https://elle.co.id/wp-content/uploads/2020/10/batik_truntum.jpg
# [!] Error:: Invalid image, not saving https://elle.co.id/wp-content/uploads/2020/10/batik_truntum.jpg
#
# [%] Downloading Image #1 from https://png.pngtree.com/thumb_back/fw800/background/20190124/pngtree-batik-truntum-image_1310.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://fasnina.com/wp-content/uploads/2020/01/motif-batik-truntum-cengkeh.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://fasnina.com/wp-content/uploads/2020/01/arti-batik-truntum-garuda.jpg
# [%] File Downloaded !
#
# ...

# %%
# !zip -r '/content/dataset_batik.zip' '/content/dataset_batik'
# Out:
#   adding: content/dataset_batik/ (stored 0%)
#   adding: content/dataset_batik/batik parang/ (stored 0%)
#   adding: content/dataset_batik/batik parang/Image_27.jpg (deflated 0%)
#   adding: content/dataset_batik/batik parang/Image_12.jpg (deflated 1%)
#   adding: content/dataset_batik/batik parang/Image_33.jpg (deflated 0%)
#   adding: content/dataset_batik/batik parang/Image_19.jpg (deflated 0%)
#   adding: content/dataset_batik/batik parang/Image_1.jpg (deflated 7%)
#   adding: content/dataset_batik/batik parang/Image_7.jpg (deflated 3%)
#   adding: content/dataset_batik/batik parang/Image_3.jpg (deflated 0%)
#   adding: content/dataset_batik/batik parang/Image_34.jpg (deflated 2%)
#   adding: content/dataset_batik/batik parang/Image_16.jpg (deflated 3%)
#   adding: content/dataset_batik/batik parang/Image_5.jpg (deflated 0%)
#   adding: content/dataset_batik/batik parang/Image_21.jpg (deflated 4%)
#   adding: content/dataset_batik/batik parang/Image_2.jpg (deflated 0%)
# ...
